# %%
import cv2

# %%
haar_features = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
# img = cv2.imread('msd.jpeg')
img = cv2.imread('team.jpg')

# %%
haar_features.detectMultiScale(img, scaleFactor=1.3)
# Out:
# array([[121,  72,  85,  85],
#        [337,  73,  99,  99],
#        [583, 403,  75,  75],
#        [ 59, 390,  80,  80],
#        [ 63, 215, 100, 100],
#        [591, 247,  73,  73],
#        [203, 562,  89,  89],
#        [346, 555,  98,  98],
#        [ 66, 575,  74,  74],
#        [529, 573,  86,  86],
#        [674, 552,  94,  94],
#        [350, 752,  79,  79],
#        [617, 746,  75,  75],
#        [156, 755,  86,  86],
#        [ 23, 657,  89,  89]], dtype=int32)

# %%
# scaleFactor - how much image size is reduced at each step
faces = haar_features.detectMultiScale(img, scaleFactor=1.3)
for (x,y,w,h) in faces:
    # img - on which we want to draw rectangle
    # (x,y) - top-left corner
    # (x+w, y+h) - bottom-right corner
    # (0,255,0) - Green Color border
    # 2 - border thickness
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)

cv2.imshow('output', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
